# %% [markdown]
# # 五子棋 AlphaZero 训练 (Google Colab)
#
# Renju 禁手规则 · MCTS + ResNet · 自动保存到 Google Drive
#
# **Runtime → Change runtime type → GPU (T4 / L4)**

# %%
REPO = "https://github.com/ZhouNingyu327/gomoku-rl.git"
# !git clone {REPO} /content/gomoku-rl
# %cd /content/gomoku-rl
# !pip install -q -e .

# %%
import torch
print("CUDA:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %%
from gomoku_rl.colab import train_colab

pipeline = train_colab(
    mount_drive=True,
    save_to_drive=True,
    train_steps=50_000,
    num_simulations=400,
    num_actors=2,
    batch_size=256,
    min_buffer_size=2000,
    save_interval=1000,
    eval_interval=5000,
)

# %%
# Download best checkpoint to local machine
from google.colab import files
import os
ckpt = "/content/gomoku_rl/checkpoints/best.pt"
if not os.path.exists(ckpt):
    ckpt = "/content/gomoku_rl/checkpoints/latest.pt"
files.download(ckpt)
